# %%
import pandas as pd

# %%
rows['session_id']

# %%
session_id = '5ba6799001ed776'
file_path = r"C:\Users\lutzb\Desktop\wt_stats\data1.xlsx"

# %%
# При чтении
df = pd.read_excel(file_path, index_col='session_id')

# Обновление
df.at[session_id, 'battle_type'] = 'Tank SB'
df.at[session_id, 'battle_bracket'] = 'full_uptier'
df.to_excel(file_path)
# Out:
# C:\Users\lutzb\AppData\Local\Temp\ipykernel_6412\1507616740.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'full_uptier' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[session_id, 'battle_bracket'] = 'full_uptier'
