# %%
### Подготовка к tkinter (следующий шаг)
import tkinter as tk
from tkinter import messagebox

def create_gui():
    window = tk.Tk()
    window.title("War Thunder Stat Parser")
    window.geometry("400x200")

    tk.Label(window, text="Скопируйте статистику боя в буфер", wraplength=350).pack(pady=20)

    tk.Button(window, text="Получить", command=on_get_click, bg="lightgreen", width=15).pack(pady=5)
    tk.Button(window, text="Закрыть", command=on_close_click, bg="lightcoral", width=15).pack(pady=5)

    window.mainloop()

# Замени блок if __name__ == "__main__": на:
# if __name__ == "__main__":
#     create_gui()

# %%
df.to_csv('battle_history.csv', mode='a', header=False, index=False) # Сохранение в CSV (история боёв)
# Автозапуск по горячей клавише
import keyboard

print("Ожидание Ctrl+Shift+S...")
keyboard.wait('ctrl+shift+s')
result = parse_battle_stats()
# сохранить в xlsx

# %%
Победа в миссии "[Превосходство] Переправа через Рейн"!

Уничтожение наземной техники             6    26760 СЛ    1588 ОИ    
    2:38    T20    M62    Tiger H1          189 очков миссии    3290 + (ПА)1645 = 4935 СЛ    71 + (ПА)142 + (Талисманы)71 = 284 ОИ
    3:19    T20    M62    Tiger H1          189 очков миссии    3290 + (ПА)1645 = 4935 СЛ    71 + (ПА)142 + (Талисманы)71 = 284 ОИ
    3:30    T20    M62    M4A3 (76) W()     189 очков миссии    3290 + (ПА)1645 = 4935 СЛ    71 + (ПА)142 + (Талисманы)71 = 284 ОИ
    3:47    T20    M62    Sd.Kfz.234/2      21 очко миссии      3290 + (ПА)1645 = 4935 СЛ    53 + (ПА)106 + (Талисманы)53 = 212 ОИ
    6:50    T86    M62    Tiger Ost         197 очков миссии    2340 + (ПА)1170 = 3510 СЛ    69 + (ПА)138 + (Талисманы)69 = 276 ОИ
    7:27    T86    M62    Chi-Ri            175 очков миссии    2340 + (ПА)1170 = 3510 СЛ    62 + (ПА)124 + (Талисманы)62 = 248 ОИ

Критические повреждения противника       6     2678 СЛ     157 ОИ    
    2:38    T20    M62    Tiger H1          57 очков миссии    329 + (ПА)165 = 494 СЛ    7 + (ПА)14 + (Талисманы)7 = 28 ОИ
    3:19    T20    M62    Tiger H1          57 очков миссии    329 + (ПА)165 = 494 СЛ    7 + (ПА)14 + (Талисманы)7 = 28 ОИ
    3:30    T20    M62    M4A3 (76) W()     57 очков миссии    329 + (ПА)165 = 494 СЛ    7 + (ПА)14 + (Талисманы)7 = 28 ОИ
    3:47    T20    M62    Sd.Kfz.234/2      6 очков миссии     329 + (ПА)165 = 494 СЛ    5 + (ПА)11 + (Талисманы)5 = 21 ОИ
    6:50    T86    M62    Tiger Ost         59 очков миссии    234 + (ПА)117 = 351 СЛ    7 + (ПА)14 + (Талисманы)7 = 28 ОИ
    7:27    T86    M62    Chi-Ri            52 очка миссии     234 + (ПА)117 = 351 СЛ    6 + (ПА)12 + (Талисманы)6 = 24 ОИ

Повреждения противника                   8     1675 СЛ     105 ОИ    
    2:31    T20       M62                 Tiger H1            20 очков миссии    165 + (ПА)83 = 248 СЛ    4 + (ПА)8 + (Талисманы)4 = 16 ОИ
    2:38    T20       M62                 Tiger H1            20 очков миссии    165 + (ПА)83 = 248 СЛ    4 + (ПА)8 + (Талисманы)4 = 16 ОИ
    3:19    T20       M62                 Tiger H1            20 очков миссии    165 + (ПА)83 = 248 СЛ    4 + (ПА)8 + (Талисманы)4 = 16 ОИ
    3:30    T20       M62                 M4A3 (76) W()       20 очков миссии    165 + (ПА)83 = 248 СЛ    4 + (ПА)8 + (Талисманы)4 = 16 ОИ
    3:47    T20       M62                 Sd.Kfz.234/2        20 очков миссии    165 + (ПА)83 = 248 СЛ    3 + (ПА)6 + (Талисманы)3 = 12 ОИ
    6:50    T86       M62                 Tiger Ost           20 очков миссии    117 + (ПА)59 = 176 СЛ    3 + (ПА)7 + (Талисманы)3 = 13 ОИ
    7:27    T86       M62                 Chi-Ri              20 очков миссии    117 + (ПА)59 = 176 СЛ    3 + (ПА)6 + (Талисманы)3 = 12 ОИ
    9:54    F8F-1B    Универсал (20мм)    Panzer IV/70(V)     11 очков миссии    55 + (ПА)28 = 83 СЛ      2 + (ПА)2 = 4 ОИ                

Захват зон                               2    16682 СЛ    1544 ОИ    
    2:08    T20    58%     295 очков миссии    5037 + (ПА)2519 = 7556 СЛ    150 + (ПА)300 + (Талисманы)150 = 600 ОИ
    7:50    T86    100%    300 очков миссии    6084 + (ПА)3042 = 9126 СЛ    236 + (ПА)472 + (Талисманы)236 = 944 ОИ

Разведка противника                      1      176 СЛ               
    8:02    T86    Tiger H1     5 очков миссии    117 + (ПА)59 = 176 СЛ

Награды                                 13     3600 СЛ               
    2:39    Спасатель танков    50 + (ПА)25 = 75 СЛ   
    3:19    Спасатель танков    50 + (ПА)25 = 75 СЛ   
    3:30    Спасатель танков    50 + (ПА)25 = 75 СЛ   
    3:30    Удар из тени!       100 + (ПА)50 = 150 СЛ 
    3:30    Мультиудар!         100 + (ПА)50 = 150 СЛ 
    3:30    Без промаха         200 + (ПА)100 = 300 СЛ
    3:48    Удар из тени!       100 + (ПА)50 = 150 СЛ 
    3:48    Мультиудар!         500 + (ПА)250 = 750 СЛ
    7:27    Спасатель танков    50 + (ПА)25 = 75 СЛ   
    7:27    Око за око          300 + (ПА)150 = 450 СЛ
    7:27    Без промаха         200 + (ПА)100 = 300 СЛ
    7:50    Серия захватов!     100 + (ПА)50 = 150 СЛ 
    9:49    Командная работа    600 + (ПА)300 = 900 СЛ

Время активности                               6766 СЛ     568 ОИ    
    F8F-1B           204 + (ПА)204 = 408 СЛ       2 + (ПА)2 = 4 ОИ                     
    M4A3E2 (76) W    0 СЛ                         0 ОИ                                 
    T20              1479 + (ПА)1479 = 2958 СЛ    65 + (ПА)130 + (Талисманы)65 = 260 ОИ
    T86              1700 + (ПА)1700 = 3400 СЛ    76 + (ПА)152 + (Талисманы)76 = 304 ОИ

Время игры                            8:46                3939 ОИ    
    F8F-1B    13%    0:47    15 + (ПА)15 = 30 ОИ                      
    T20       87%    3:14    398 + (ПА)796 + (Талисманы)398 = 1592 ОИ 
    T86       93%    4:45    579 + (ПА)1159 + (Талисманы)579 = 2317 ОИ

Награда за победу                             25565 СЛ               

Бонус за мастерство                                        993 ОИ    
    F8F-1B           II    10 ОИ 
    M4A3E2 (76) W    II    0 ОИ  
    T20              II    462 ОИ
    T86              II    521 ОИ

Заработано: 83902 СЛ, 8894 СОИ
Активность: 90%
Повреждённая техника: T20
Автоматический ремонт всей техники: -1490 СЛ
Автоматическая закупка боеприпасов и "пополнения экипажа": -625 СЛ

Исследуемая техника: 
B-29A-BN: 48 ОИ
M3 Bradley: 3070 ОИ

Прогресс исследований: 
F8F-1B - Новые 12.7-мм пулемёты: 48 ОИ
T86 - Знак отличия: 4687 ОИ

Сессия: 5354a840003ecc3
Итого: 81787 СЛ, 8894 СОИ, 7853 ОИ

# %%
Победа в миссии "[Превосходство #1] Линия Мажино (зима)"!

Уничтожение наземной техники              7    20790 СЛ    1132 ОИ    
    5:51     Т-54 (1947)    БР-412Д    T26E5       175 очков миссии    1980 + (ПА)990 = 2970 СЛ    79 + (ПА)79 = 158 ОИ
    6:00     Т-54 (1947)    БР-412Д    T26E1-1     175 очков миссии    1980 + (ПА)990 = 2970 СЛ    79 + (ПА)79 = 158 ОИ
    7:45     Т-54 (1947)    БР-412Д    FV4202      197 очков миссии    1980 + (ПА)990 = 2970 СЛ    88 + (ПА)88 = 176 ОИ
    8:14     Т-54 (1947)    БР-412Д    M41A1       155 очков миссии    1980 + (ПА)990 = 2970 СЛ    74 + (ПА)74 = 148 ОИ
    9:38     Т-54 (1947)    БР-412Д    T26E1-1     175 очков миссии    1980 + (ПА)990 = 2970 СЛ    79 + (ПА)79 = 158 ОИ
    11:24    Т-54 (1947)    БР-412Д    Strv 81     200 очков миссии    1980 + (ПА)990 = 2970 СЛ    93 + (ПА)93 = 186 ОИ
    12:33    Т-54 (1947)    БР-412Д    M41A1       155 очков миссии    1980 + (ПА)990 = 2970 СЛ    74 + (ПА)74 = 148 ОИ

Критические повреждения противника        7     2079 СЛ     112 ОИ    
    5:51     Т-54 (1947)    БР-412Д    T26E5       52 очка миссии     198 + (ПА)99 = 297 СЛ    8 + (ПА)8 = 16 ОИ
    6:00     Т-54 (1947)    БР-412Д    T26E1-1     52 очка миссии     198 + (ПА)99 = 297 СЛ    8 + (ПА)8 = 16 ОИ
    7:45     Т-54 (1947)    БР-412Д    FV4202      59 очков миссии    198 + (ПА)99 = 297 СЛ    9 + (ПА)9 = 18 ОИ
    8:14     Т-54 (1947)    БР-412Д    M41A1       47 очков миссии    198 + (ПА)99 = 297 СЛ    7 + (ПА)7 = 14 ОИ
    9:38     Т-54 (1947)    БР-412Д    T26E1-1     52 очка миссии     198 + (ПА)99 = 297 СЛ    8 + (ПА)8 = 16 ОИ
    11:24    Т-54 (1947)    БР-412Д    Strv 81     60 очков миссии    198 + (ПА)99 = 297 СЛ    9 + (ПА)9 = 18 ОИ
    12:33    Т-54 (1947)    БР-412Д    M41A1       47 очков миссии    198 + (ПА)99 = 297 СЛ    7 + (ПА)7 = 14 ОИ

Повреждения противника                   14     2412 СЛ     130 ОИ    
    2:40     ИС-6           БР-471Д           T26E5       20 очков миссии    208 + (ПА)104 = 312 СЛ    4 + (ПА)8 + (Талисманы)4 = 16 ОИ
    2:55     ИС-6           БР-471Д           T26E5       20 очков миссии    208 + (ПА)104 = 312 СЛ    4 + (ПА)8 + (Талисманы)4 = 16 ОИ
    5:33     Т-54 (1947)    БР-412Д           T26E1-1     20 очков миссии    99 + (ПА)50 = 149 СЛ      4 + (ПА)4 = 8 ОИ                
    5:37     Т-54 (1947)    БС-41 (12.7мм)    T26E1-1     20 очков миссии    99 + (ПА)50 = 149 СЛ      4 + (ПА)4 = 8 ОИ                
    5:42     Т-54 (1947)    МДЗ (12.7мм)      T26E1-1     20 очков миссии    99 + (ПА)50 = 149 СЛ      4 + (ПА)4 = 8 ОИ                
    5:43     Т-54 (1947)    БР-412Д           T26E1-1     20 очков миссии    99 + (ПА)50 = 149 СЛ      4 + (ПА)4 = 8 ОИ                
    5:51     Т-54 (1947)    БР-412Д           T26E5       20 очков миссии    99 + (ПА)50 = 149 СЛ      4 + (ПА)4 = 8 ОИ                
    6:00     Т-54 (1947)    БР-412Д           T26E1-1     20 очков миссии    99 + (ПА)50 = 149 СЛ      4 + (ПА)4 = 8 ОИ                
    7:45     Т-54 (1947)    БР-412Д           FV4202      20 очков миссии    99 + (ПА)50 = 149 СЛ      4 + (ПА)4 = 8 ОИ                
    8:14     Т-54 (1947)    БР-412Д           M41A1       20 очков миссии    99 + (ПА)50 = 149 СЛ      4 + (ПА)4 = 8 ОИ                
    9:38     Т-54 (1947)    БР-412Д           T26E1-1     20 очков миссии    99 + (ПА)50 = 149 СЛ      4 + (ПА)4 = 8 ОИ                
    11:24    Т-54 (1947)    БР-412Д           Strv 81     20 очков миссии    99 + (ПА)50 = 149 СЛ      5 + (ПА)5 = 10 ОИ               
    12:21    Т-54 (1947)    БР-412Д           M41A1       20 очков миссии    99 + (ПА)50 = 149 СЛ      4 + (ПА)4 = 8 ОИ                
    12:33    Т-54 (1947)    БР-412Д           M41A1       20 очков миссии    99 + (ПА)50 = 149 СЛ      4 + (ПА)4 = 8 ОИ                

Захват зон                                3    23166 СЛ    1806 ОИ    
    6:45     Т-54 (1947)    100%    300 очков миссии    5148 + (ПА)2574 = 7722 СЛ    301 + (ПА)301 = 602 ОИ
    10:08    Т-54 (1947)    100%    300 очков миссии    5148 + (ПА)2574 = 7722 СЛ    301 + (ПА)301 = 602 ОИ
    11:58    Т-54 (1947)    99%     300 очков миссии    5148 + (ПА)2574 = 7722 СЛ    301 + (ПА)301 = 602 ОИ

Награды                                  21     5550 СЛ               
    5:46     Несокрушимый        300 + (ПА)150 = 450 СЛ
    5:52     Спасатель танков    50 + (ПА)25 = 75 СЛ   
    6:01     Спасатель танков    50 + (ПА)25 = 75 СЛ   
    6:01     Мультиудар!         100 + (ПА)50 = 150 СЛ 
    7:45     Спасатель танков    50 + (ПА)25 = 75 СЛ   
    7:45     Без промаха         200 + (ПА)100 = 300 СЛ
    8:15     Мультиудар!         100 + (ПА)50 = 150 СЛ 
    8:15     Без промаха         200 + (ПА)100 = 300 СЛ
    9:19     Командная работа    600 + (ПА)300 = 900 СЛ
    9:39     Профессионал        150 + (ПА)75 = 225 СЛ 
    9:39     Без промаха         200 + (ПА)100 = 300 СЛ
    10:08    Серия захватов!     100 + (ПА)50 = 150 СЛ 
    11:25    Спасатель танков    50 + (ПА)25 = 75 СЛ   
    11:25    Око за око          300 + (ПА)150 = 450 СЛ
    11:25    Профессионал        50 + (ПА)25 = 75 СЛ   
    11:25    Без промаха         200 + (ПА)100 = 300 СЛ
    11:41    Командная работа    600 + (ПА)300 = 900 СЛ
    11:58    Серия захватов!     100 + (ПА)50 = 150 СЛ 
    12:34    Спасатель танков    50 + (ПА)25 = 75 СЛ   
    12:34    Профессионал        50 + (ПА)25 = 75 СЛ   
    12:34    Без промаха         200 + (ПА)100 = 300 СЛ

Время активности                                4368 СЛ     426 ОИ    
    ИС-6           1084 + (ПА)1084 = 2168 СЛ    54 + (ПА)108 + (Талисманы)54 = 216 ОИ
    Т-54 (1947)    1100 + (ПА)1100 = 2200 СЛ    105 + (ПА)105 = 210 ОИ               

Время игры                            12:33                4360 ОИ    
    ИС-6           60%     2:34    258 + (ПА)516 + (Талисманы)258 = 1032 ОИ
    Т-54 (1947)    100%    9:59    1664 + (ПА)1664 = 3328 ОИ               

Награда за победу                              24667 СЛ               

Бонус за мастерство                                        1832 ОИ    
    ИС-6           II    160 ОИ 
    Т-54 (1947)    II    1672 ОИ

Заработано: 83032 СЛ, 9798 СОИ
Активность: 96%
Повреждённая техника: Т-54 (1947), ИС-6
Автоматический ремонт всей техники: -1869 СЛ
Автоматическая закупка боеприпасов и "пополнения экипажа": -2120 СЛ

Исследуемая техника: 
Т-72А: 9798 ОИ

Сессия: 53517670002a0ab
Итого: 79043 СЛ, 9798 СОИ, 9798 ОИ

# %%
Поражение в миссии "[Операция] Загадочная долина. Космопорт".

Уничтожение авиации                       1    1991 СЛ      86 ОИ    
    5:54    Су-9    Стандарт (23мм)    A-4B (ИИ)    225 очков миссии    — (полная награда)    1327 + (ПА)664 = 1991 СЛ    39 + (ПА)39 + (Усилитель)8 = 86 ОИ

Уничтожение наземной техники              8    2904 СЛ     128 ОИ    
    7:18     Су-9    Стандарт (23мм)    Гаубица (ИИ)    34 очка миссии    242 + (ПА)121 = 363 СЛ    7 + (ПА)7 + (Усилитель)2 = 16 ОИ
    8:06     Су-9    Стандарт (23мм)    Гаубица (ИИ)    34 очка миссии    242 + (ПА)121 = 363 СЛ    7 + (ПА)7 + (Усилитель)2 = 16 ОИ
    8:09     Су-9    Стандарт (23мм)    Гаубица (ИИ)    34 очка миссии    242 + (ПА)121 = 363 СЛ    7 + (ПА)7 + (Усилитель)2 = 16 ОИ
    8:39     Су-9    Стандарт (23мм)    Гаубица (ИИ)    34 очка миссии    242 + (ПА)121 = 363 СЛ    7 + (ПА)7 + (Усилитель)2 = 16 ОИ
    9:23     Су-9    Стандарт (23мм)    Гаубица (ИИ)    34 очка миссии    242 + (ПА)121 = 363 СЛ    7 + (ПА)7 + (Усилитель)2 = 16 ОИ
    9:25     Су-9    Стандарт (23мм)    Гаубица (ИИ)    34 очка миссии    242 + (ПА)121 = 363 СЛ    7 + (ПА)7 + (Усилитель)2 = 16 ОИ
    9:33     Су-9    Стандарт (23мм)    Гаубица (ИИ)    34 очка миссии    242 + (ПА)121 = 363 СЛ    7 + (ПА)7 + (Усилитель)2 = 16 ОИ
    16:16    Су-9    Стандарт (37мм)    Гаубица (ИИ)    34 очка миссии    242 + (ПА)121 = 363 СЛ    7 + (ПА)7 + (Усилитель)2 = 16 ОИ

Критические повреждения противника        1     200 СЛ       9 ОИ    
    5:54    Су-9    Стандарт (23мм)    A-4B (ИИ)    75 очков миссии    133 + (ПА)67 = 200 СЛ    4 + (ПА)4 + (Усилитель)1 = 9 ОИ

Повреждения противника                   27     732 СЛ      15 ОИ    
    5:54     Су-9    Стандарт (23мм)    A-4B (ИИ)       13 очков миссии    66 + (ПА)34 = 100 СЛ    2 + (ПА)2 + (Усилитель)1 = 5 ОИ
    5:54     Су-9    Стандарт (23мм)    A-4B (ИИ)       13 очков миссии    66 + (ПА)34 = 100 СЛ    2 + (ПА)2 + (Усилитель)1 = 5 ОИ
    5:55     Су-9    Стандарт (23мм)    A-4B (ИИ)       13 очков миссии    66 + (ПА)34 = 100 СЛ    2 + (ПА)2 + (Усилитель)1 = 5 ОИ
    6:49     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    6:50     Су-9    Стандарт (37мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    7:01     Су-9    Стандарт (37мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    7:18     Су-9    Стандарт (37мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    7:18     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    7:20     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    7:20     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    7:54     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    8:00     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    8:06     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    8:09     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    8:09     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    8:38     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    8:39     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    8:41     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    8:46     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    9:21     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    9:23     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    9:23     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    9:25     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    9:25     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    9:33     Су-9    Стандарт (23мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    16:15    Су-9    Стандарт (37мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           
    16:16    Су-9    Стандарт (37мм)    Гаубица (ИИ)    6 очков миссии     12 + (ПА)6 = 18 СЛ      0 ОИ                           

Взлёты                                    2                172 ОИ    
    1:29     Су-9    39 + (ПА)39 + (Усилитель)8 = 86 ОИ
    14:11    Су-9    39 + (ПА)39 + (Усилитель)8 = 86 ОИ

Посадки                                   1                172 ОИ    
    12:25    Су-9    78 + (ПА)78 + (Усилитель)16 = 172 ОИ

Время активности                               3200 СЛ      66 ОИ    
    Су-9    1600 + (ПА)1600 = 3200 СЛ    30 + (ПА)30 + (Усилитель)6 = 66 ОИ

Время игры                            17:44               4574 ОИ    
    Су-9    63%    17:44    2079 + (ПА)2079 + (Усилитель)416 = 4574 ОИ

Награда за участие в миссии                    1805 СЛ               

Заработано: 10832 СЛ, 5222 СОИ
Активность: 63%
Повреждённая техника: Су-9

Исследуемая техника: 
ДБ-3Б: 522 ОИ

Прогресс исследований: 
Су-9 - Обработка фюзеляжа: 4000 ОИ

Использованные предметы: 
Активные усилители на ОИ: 
Общий: +20%ОИ
* Личный усилитель
+20%ОИ, даёт (+20%ОИ).

Сессия: 53a959f001f10b1
Итого: 10832 СЛ, 5222 СОИ, 4522 ОИ

# %%
import pyperclip
import re
import pandas as pd
import os
from datetime import datetime

# %%
# парсер версия 1
def parse_battle_stats():
    imported_game_log = pyperclip.paste()
    if not imported_game_log.strip():
        print("❌ Буфер обмена пуст. Скопируй статистику боя и запусти скрипт снова.")
        return None

    # --- Результат: Победа / Поражение ---
    result_match = re.search(r'(Победа|Поражение) в миссии', imported_game_log)
    result = result_match.group(1) if result_match else "Неизвестно"

    # --- Название миссии ---
    mission_match = re.search(r'миссии\s+"([^"]+)"', imported_game_log)
    mission = mission_match.group(1) if mission_match else "Неизвестно"

    # --- Итого: СЛ, СОИ (FRP), ОИ (RP) — только последнее вхождение ---
    total_matches = re.findall(r'Итого:\s*(\d+)\s*СЛ,\s*(\d+)\s*СОИ,\s*(\d+)\s*ОИ', imported_game_log)
    if not total_matches:
        print("❌ Не удалось найти ни одного вхождения 'Итого'.")
        return None

    # Берём ПОСЛЕДНЕЕ вхождение (финальные итоги)
    last_match = total_matches[-1]
    total_sl = int(last_match[0])   # Silver Lions
    total_frp = int(last_match[1])  # Free Research Points
    total_rp = int(last_match[2])   # Research Points

    # --- Очки миссии ---
    mission_points = re.findall(r'(\d+)\s*очк(?:о|а|ов)\s*миссии', imported_game_log)
    total_mission_points = sum(int(x) for x in mission_points)

    # --- Сессия ---
    session_match = re.search(r'Сессия:\s*([a-f0-9]+)', imported_game_log)
    session_id = session_match.group(1) if session_match else None
    if not session_id:
        print("❌ Не удалось найти session_id.")
        return None

    # --- Активность (%) ---
    activity_match = re.search(r'Активность:\s*(\d+)%', imported_game_log)
    activity_percent = int(activity_match.group(1)) if activity_match else None

    # --- Использованная техника ---
    vehicles = set()

    # Паттерн 1: "Время активности" — ищем текст до "Цифры + (ПА)"
    pattern_active = r'^\s*(.+?)\s+\d+\s*\+\s*$$ПА$$'
    # Паттерн 2: "Время игры" — ищем текст до "95% ... 4:51"
    pattern_game = r'^\s*(.+?)\s+\d+%.*?\d+:\d+'

    active_time_matches = re.findall(pattern_active, imported_game_log, re.MULTILINE)
    game_time_matches = re.findall(pattern_game, imported_game_log, re.MULTILINE)
    
    all_vehicles = active_time_matches + game_time_matches

    for v in all_vehicles:
        cleaned = re.sub(r'\s+', ' ', v.strip())
        # Исключаем ложные срабатывания (например, "Заработано", "Итого")
        if cleaned and not re.match(r'^[0-9\[\]"]', cleaned) and len(cleaned) > 1:
            vehicles.add(cleaned)

    vehicles = ", ".join(sorted(vehicles)) if vehicles else "Неизвестно"

    return {
        'session_id': session_id,
        'vehicles': vehicles,
        'total_sl': total_sl,
        'total_frp': total_frp,
        'total_rp': total_rp,
        'total_mission_points': total_mission_points,
        'result': result,
        'mission': mission,
        'activity_percent': activity_percent,
    }

def save_to_excel(data):
    file_path = r"C:\Users\lutzb\Desktop\wt_stats\data.xlsx"
    columns = [
        'session_id', 'vehicles', 'total_sl', 'total_frp', 'total_rp',
        'total_mission_points', 'result', 'mission', 'activity_percent'
    ]

    try:
        # Попробуем прочитать существующий файл
        df = pd.read_excel(file_path, engine='openpyxl')
        # Преобразуем в список словарей (или просто добавим строку)
        df_new = pd.DataFrame([data], columns=columns)
        df_combined = pd.concat([df, df_new], ignore_index=True)
    except FileNotFoundError:
        # Если файла нет — создаём с нуля
        df_combined = pd.DataFrame([data], columns=columns)
    except Exception as e:
        print(f"⚠️ Ошибка при чтении файла: {e}. Создаём новый.")
        df_combined = pd.DataFrame([data], columns=columns)

    # Сохраняем обратно в Excel
    df_combined.to_excel(file_path, index=False, engine='openpyxl')
    print(f"✅ Добавлено в Excel: {file_path}")

# === ЗАПУСК ===
if __name__ == "__main__":
    print("🔄 Обработка буфера обмена...")
    data = parse_battle_stats()
    if data:
        print("\n📋 Извлечено:")
        for k, v in data.items():
            print(f"  {k}: {v}")
        save_to_excel(data)
    else:
        print("❌ Обработка не удалась.")
# Out:
# 🔄 Обработка буфера обмена...
#
# 📋 Извлечено:
#   session_id: 53685d2000ad9df
#   vehicles: Ла-9
#   total_sl: 0
#   total_frp: 952
#   total_rp: 1999
#   total_mission_points: 25
#   result: Поражение
#   mission: [Операция] Битва за Тунис
#   activity_percent: 34
# ✅ Добавлено в Excel: C:\Users\lutzb\Desktop\wt_stats\data.xlsx

# %%
# парсер версия 2
def parse_battle_stats():
    imported_game_log = pyperclip.paste()
    if not imported_game_log.strip():
        print("❌ Буфер обмена пуст. Скопируй статистику боя и запусти скрипт снова.")
        return None

    # --- Результат: Победа / Поражение ---
    result_match = re.search(r'(Победа|Поражение) в миссии', imported_game_log)
    result = result_match.group(1) if result_match else "Неизвестно"

    # --- Название миссии ---
    mission_match = re.search(r'миссии\s+"([^"]+)"', imported_game_log)
    mission = mission_match.group(1) if mission_match else "Неизвестно"

    # --- Итого: СЛ, СОИ (FRP), ОИ (RP) — только последнее вхождение ---
    total_matches = re.findall(r'Итого:\s*(\d+)\s*СЛ,\s*(\d+)\s*СОИ,\s*(\d+)\s*ОИ', imported_game_log)
    if not total_matches:
        print("❌ Не удалось найти ни одного вхождения 'Итого'.")
        return None

    # Берём ПОСЛЕДНЕЕ вхождение (финальные итоги)
    last_match = total_matches[-1]
    total_sl = int(last_match[0])   # Silver Lions
    total_frp = int(last_match[1])  # Free Research Points
    total_rp = int(last_match[2])   # Research Points

    # --- Очки миссии ---
    mission_points = re.findall(r'(\d+)\s*очк(?:о|а|ов)\s*миссии', imported_game_log)
    total_mission_points = sum(int(x) for x in mission_points)

    # --- Сессия ---
    session_match = re.search(r'Сессия:\s*([a-f0-9]+)', imported_game_log)
    session_id = session_match.group(1) if session_match else None
    if not session_id:
        print("❌ Не удалось найти session_id.")
        return None

    # --- Активность (%) ---
    activity_match = re.search(r'Активность:\s*(\d+)%', imported_game_log)
    activity_percent = int(activity_match.group(1)) if activity_match else None

    # --- Использованная техника ---
    vehicles = set()

    # Паттерн 1: "Время активности" — ищем текст до "Цифры + (ПА)"
    pattern_active = r'^\s*(.+?)\s+\d+\s*\+\s*$$ПА$$'
    # Паттерн 2: "Время игры" — ищем текст до "95% ... 4:51"
    pattern_game = r'^\s*(.+?)\s+\d+%.*?\d+:\d+'

    active_time_matches = re.findall(pattern_active, imported_game_log, re.MULTILINE)
    game_time_matches = re.findall(pattern_game, imported_game_log, re.MULTILINE)
    
    all_vehicles = active_time_matches + game_time_matches

    for v in all_vehicles:
        cleaned = re.sub(r'\s+', ' ', v.strip())
        # Исключаем ложные срабатывания (например, "Заработано", "Итого")
        if cleaned and not re.match(r'^[0-9\[\]"]', cleaned) and len(cleaned) > 1:
            vehicles.add(cleaned)

    vehicles = ", ".join(sorted(vehicles)) if vehicles else "Неизвестно"

    return {
        'session_id': session_id,
        'vehicles': vehicles,
        'total_sl': total_sl,
        'total_frp': total_frp,
        'total_rp': total_rp,
        'total_mission_points': total_mission_points,
        'result': result,
        'mission': mission,
        'activity_percent': activity_percent,
    }

def save_to_excel(data):
    file_path = r'D:\data.xlsx' # r"C:\Users\lutzb\Desktop\wt_stats\data.xlsx"
    columns = [
        'session_id', 'vehicles', 'total_sl', 'total_frp', 'total_rp',
        'total_mission_points', 'result', 'mission', 'activity_percent'
    ]

    try:
        df = pd.read_excel(file_path, engine='openpyxl')
    except (FileNotFoundError, ValueError):
        df = pd.DataFrame(columns=columns)

    # Удаляем строку с таким session_id, если есть
    df = df[df['session_id'] != data['session_id']]

    # Добавляем новую
    new_row = pd.DataFrame([data], columns=columns)
    df = pd.concat([df, new_row], ignore_index=True)

    # Сохраняем
    df.to_excel(file_path, index=False, engine='openpyxl')
    print(f"✅ Обновлено: {data['session_id']}")

# === ЗАПУСК ===
if __name__ == "__main__":
    print("🔄 Обработка буфера обмена...")
    data = parse_battle_stats()
    if data:
        print("\n📋 Извлечено:")
        for k, v in data.items():
            print(f"  {k}: {v}")
        save_to_excel(data)
    else:
        print("❌ Обработка не удалась.")
# Out:
# 🔄 Обработка буфера обмена...
#
# 📋 Извлечено:
#   session_id: 53517670002a0ab
#   vehicles: ИС-6, Т-54 (1947)
#   total_sl: 79043
#   total_frp: 9798
#   total_rp: 9798
#   total_mission_points: 2781
#   result: Победа
#   mission: [Превосходство #1] Линия Мажино (зима)
#   activity_percent: 96
# ✅ Обновлено: 53517670002a0ab
